# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px

# %%
# df = pd.read_csv('Meteorite_Landings (1).csv')
# df.head(10)

df = pd.read_csv('dataset_instagram-scraper_2023-09-14_02-37-11-197.csv')
df.head(10)
# Out:
#                   id  likesCount  \
# 0  17987095331151098           0
# 1  17944246670601518           0
# 2  18026452528718242           0
# 3  17899649126853129           0
# 4  17990489384255522           0
# 5  18275960017152185           0
# 6  18005537692953789           0
# 7  18029110627610038           0
# 8  18063042325402453           0
# 9  17844908499063578           0
#
#                                   ownerProfilePicUrl      ownerUsername  \
# 0  https://scontent-dfw5-2.cdninstagram.com/v/t51...        semiha_3413
# 1  https://scontent-dfw5-1.cdninstagram.com/v/t51...         mauren2215
# 2  https://scontent-dfw5-1.cdninstagram.com/v/t51...      eyll_ozarslan
# 3  https://scontent-dfw5-2.cdninstagram.com/v/t51...      marysigsworth
# 4  https://scontent-dfw5-1.cdninstagram.com/v/t51...           itselyas
# 5  https://scontent-dfw5-1.cdninstagram.com/v/t51...           itselyas
# 6  https://scontent-dfw5-2.cdninstagram.com/v/t51...       siha.__.gmal
# ...

# %%
df.shape
# Out:
# (45716, 12)

# %%
df['States'].isna().sum().sum()
# Out:
# 44057

# %%
df['Counties'].isna().sum().sum()
# Out:
# 44057

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4  107,000   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1,914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2,167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
# ...

# %%
df.value_counts()
# Out:
# name               id     nametype  recclass         mass (g)   fall   year    reclat     reclong      GeoLocation               States  Counties
# Abbott             5      Valid     H3-6             21,100     Found  1951.0  36.300000  -104.283330  (36.3, -104.28333)        11.0    2,537       1
# Prairie Dog Creek  18882  Valid     H3.7             2,900      Found  1893.0  39.633330  -100.500000  (39.63333, -100.5)        17.0    1,941       1
# Rabbit Dry Lake    22366  Valid     L6               20         Found  2000.0  34.445670  -117.010830  (34.44567, -117.01083)    8.0     78          1
# Quinn Canyon       22364  Valid     Iron, IIIAB      1,450,000  Found  1908.0  38.083330  -115.533330  (38.08333, -115.53333)    10.0    2,401       1
# Quartzsite         35634  Valid     L4               69.7       Found  2002.0  33.680850  -114.195800  (33.68085, -114.1958)     7.0     7           1
# ...

# %%
df = df[(df.year >= 860) & (df.year <= 2016)]
df = df[((df.reclong <= 180) & (df.reclong >= -180)) & ((df.reclat != 0) | (df.reclong != 0))]
sns.distplot(df.year)
plt.title('year distribution');
# Out:
# C:\Users\kunal\AppData\Local\Temp\ipykernel_10480\3180135488.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.year)

# %%
sns.distplot(df.reclong)
sns.distplot(df.reclat)
plt.title('lat and long distribution')
plt.legend(['longitude', 'latitude']);
# Out:
# C:\Users\kunal\AppData\Local\Temp\ipykernel_10480\3909000016.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.reclong)
# C:\Users\kunal\AppData\Local\Temp\ipykernel_10480\3909000016.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.reclat)

# %%
# Calculate value counts
value_counts = df["fall"].value_counts()

# Create a pie chart using Seaborn
plt.figure(figsize=(6, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=180)
plt.title('Meteor Fall Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the pie chart
plt.show()

# %%
df['recclass'].value_counts()
# Out:
# recclass
# L6                6529
# H5                5590
# H4                3324
# H6                3231
# L5                2725
#                   ...
# LL7(?)               1
# LL6(?)               1
# H3.5-4               1
# L3.9-6               1
# Mesosiderite-C       1
# Name: count, Length: 394, dtype: int64

# %%
import json


text= "{\"reviews\":[{\"id\":1679757,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"I love the colour and the material of this T-shirt! I got this for my boyfriend in two colours! Green and Orange and he absolutely loves it as well, it’s very soft and the fabrics is breathable\",\"textLength\":193,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"22592452132\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[{\"id\":3},{\"id\":10}]},\"reviewedDate\":\"2022-06-21T12:41:28-04:00\",\"purchaseDate\":\"2022-06-09T06:47:49-04:00\",\"dateCreated\":\"2022-06-14T10:49:56-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816142012\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816142.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"M\",\"valueLabel\":\"M\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Orange\",\"valueLabel\":\"Orange\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]}]}]},{\"id\":282125,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"Perfect fit and good quality cloth material. For anyone who wishes to get a good body fit, this is the one to go for. \\nIf you want a more loose fit, go for the relaxed fit version.\",\"textLength\":180,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"15519737452\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[]},\"reviewedDate\":\"2021-01-11T01:32:17-05:00\",\"purchaseDate\":\"2021-01-06T15:16:52-05:00\",\"dateCreated\":\"2021-01-10T10:26:14-05:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816002013\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816002.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Black\",\"valueLabel\":\"Black\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"L\",\"valueLabel\":\"L\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]},{\"type\":\"colorNames\",\"typeLabel\":\"colorNames\",\"values\":[{\"value\":\"Black\",\"valueLabel\":\"Black\"}]}]}]},{\"id\":630930,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"Loved it!!! It's a basic tshirt but the color is very rich and good for outdoor, casual wear, weekend drive or Friday dinner. Pair it with a denim and sneakers , looks beautiful.\",\"textLength\":178,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"17151386462\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[]},\"reviewedDate\":\"2021-07-02T04:07:09-04:00\",\"purchaseDate\":\"2021-06-02T02:52:44-04:00\",\"dateCreated\":\"2021-07-01T15:13:16-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816023012\",\"title\":\"Round-neck T-shirt Regular Fit\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816023.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"M\",\"valueLabel\":\"M\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Grey\",\"valueLabel\":\"Grey\"}]}]}]},{\"id\":459947,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"This is a good quality t-shirt at such a reasonable price. I would buy more in the coming days, as it is far better compared to other brands at this price.  \\n\\nGive it a try.\",\"textLength\":173,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"16475767822\",\"dimensions\":[],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[]},\"reviewedDate\":\"2021-04-09T01:44:00-04:00\",\"purchaseDate\":\"2021-03-31T23:16:50-04:00\",\"dateCreated\":\"2021-04-05T07:41:01-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816023012\",\"title\":\"Round-neck T-shirt Regular Fit\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816023.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"M\",\"valueLabel\":\"M\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Grey\",\"valueLabel\":\"Grey\"}]}]}]},{\"id\":1679750,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"I love the colour and the material of this T-shirt! I got this for my boyfriend in two colours! He absolutely loves it as well, it’s very soft and the fabrics is breathable\",\"textLength\":172,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"22592452132\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[{\"id\":3},{\"id\":10}]},\"reviewedDate\":\"2022-06-21T12:41:28-04:00\",\"purchaseDate\":\"2022-06-09T06:47:49-04:00\",\"dateCreated\":\"2022-06-14T10:48:57-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816138012\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816138.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"M\",\"valueLabel\":\"M\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Green\",\"valueLabel\":\"Green\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]}]}]},{\"id\":1494586,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"Amazing cotton T-shirt and loving the long length of T-shirt. \\nAlso I’m loving how this shade of blue is amazing and different. Looks a very chilled out and yet lil formal.\",\"textLength\":172,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"21793151742\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[]},\"reviewedDate\":\"2022-04-18T04:23:50-04:00\",\"purchaseDate\":\"2022-04-13T23:46:31-04:00\",\"dateCreated\":\"2022-04-17T23:14:36-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816128013\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816128.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Blue\",\"valueLabel\":\"Blue\"}]},{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"L\",\"valueLabel\":\"L\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]}]}]},{\"id\":375339,\"locale\":\"en_IN\",\"rating\":4,\"title\":null,\"text\":\"T-shirt quality is very good and also the material is very soft. It fits very well and as what I expected H&M makes my expection clear. Thank you H&Moore this good product.\",\"textLength\":172,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"15861702162\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[]},\"reviewedDate\":\"2021-02-18T01:59:31-05:00\",\"purchaseDate\":\"2021-02-05T18:46:16-05:00\",\"dateCreated\":\"2021-02-17T21:49:14-05:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816002012\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816002.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Black\",\"valueLabel\":\"Black\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"M\",\"valueLabel\":\"M\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]},{\"type\":\"colorNames\",\"typeLabel\":\"colorNames\",\"values\":[{\"value\":\"Black\",\"valueLabel\":\"Black\"}]}]}]},{\"id\":1968779,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"I loved it. The material and it’s comfort, both were amazing. It fits perfectly and I felt so fresh after wearing it. One of the best purchases I’ve ever done. \\uD83D\\uDE0D\\uD83D\\uDE0D\\uD83D\\uDE0D\\uD83D\\uDE0D\",\"textLength\":168,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"24160132052\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[{\"id\":4},{\"id\":12}]},\"reviewedDate\":\"2022-09-15T08:30:48-04:00\",\"purchaseDate\":\"2022-09-10T08:36:04-04:00\",\"dateCreated\":\"2022-09-14T10:38:40-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816091013\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816091.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Green\",\"valueLabel\":\"Green\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"L\",\"valueLabel\":\"L\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]}]}]},{\"id\":1670517,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"The shirt is indeed essential for so many outfits. I love the quality of the fabric used and it feels good to the touch. It goes so well with shirts, jackets, blazers.\",\"textLength\":167,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"22565937752\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[{\"id\":4},{\"id\":11}]},\"reviewedDate\":\"2022-06-11T15:58:43-04:00\",\"purchaseDate\":\"2022-06-08T00:16:37-04:00\",\"dateCreated\":\"2022-06-10T13:53:37-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816001014\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816001.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"XL\",\"valueLabel\":\"XL\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"White\",\"valueLabel\":\"White\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]},{\"type\":\"colorNames\",\"typeLabel\":\"colorNames\",\"values\":[{\"value\":\"White\",\"valueLabel\":\"White\"}]}]}]},{\"id\":802039,\"locale\":\"en_IN\",\"rating\":5,\"title\":null,\"text\":\"This is one of the best-coloured T-shirts I've ever worn.\\nGo for it don't think about it and size fits your choice, not to doublethink.\\nSuper Comfortable and light.\",\"textLength\":164,\"csFlag\":false,\"inappropriateFlag\":false,\"reviewedFlag\":true,\"autoModerated\":false,\"published\":true,\"incentivized\":false,\"upVotes\":0,\"downVotes\":0,\"orderId\":\"18177478042\",\"dimensions\":[{\"type\":2,\"dimensionId\":1,\"dimensionLabel\":\"True to Size\",\"value\":2,\"label\":[\"Spot on\"]}],\"responses\":[],\"tags\":[],\"media\":{\"photo\":[],\"video\":[],\"audio\":[]},\"user\":{\"nickName\":null,\"firstName\":null,\"lastName\":null,\"emailAddress\":null,\"externalId\":null,\"city\":null,\"state\":null,\"country\":null,\"ageRange\":null,\"badge\":null,\"shopperProfiles\":[]},\"reviewedDate\":\"2021-08-27T10:58:39-04:00\",\"purchaseDate\":\"2021-08-24T08:16:36-04:00\",\"dateCreated\":\"2021-08-27T03:09:14-04:00\",\"acceptedTermsAndConditions\":true,\"catalogItems\":[{\"sku\":\"0685816101013\",\"title\":\"Regular Fit Round-neck T-shirt\",\"url\":\"https://www2.hm.com/en_in/productpage.0685816101.html\",\"category\":null,\"reviewCount\":5018,\"ratingCount\":29324,\"averageRating\":4.6,\"ratingBreakdown\":{\"1\":669,\"2\":552,\"3\":1697,\"4\":5393,\"5\":21013},\"attributes\":[{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\"}]},{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"L\",\"valueLabel\":\"L\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Purple\",\"valueLabel\":\"Purple\"}]}]}]}],\"offset\":10,\"limit\":10,\"total\":10000,\"filters\":{\"attributes\":[{\"type\":\"ageGroup\",\"typeLabel\":\"ageGroup\",\"values\":[{\"value\":\"Adult\",\"valueLabel\":\"Adult\",\"count\":24041,\"filter\":\"pa('ageGroup:Adult')\"}]},{\"type\":\"assortmentType\",\"typeLabel\":\"assortmentType\",\"values\":[{\"value\":\"Clothing\",\"valueLabel\":\"Clothing\",\"count\":29323,\"filter\":\"pa('assortmentType:Clothing')\"}]},{\"type\":\"color\",\"typeLabel\":\"color\",\"values\":[{\"value\":\"Red\",\"valueLabel\":\"Red\",\"count\":1489,\"filter\":\"pa('color:Red')\"},{\"value\":\"Black\",\"valueLabel\":\"Black\",\"count\":3318,\"filter\":\"pa('color:Black')\"},{\"value\":\"White\",\"valueLabel\":\"White\",\"count\":3537,\"filter\":\"pa('color:White')\"},{\"value\":\"Grey\",\"valueLabel\":\"Grey\",\"count\":3637,\"filter\":\"pa('color:Grey')\"},{\"value\":\"Green\",\"valueLabel\":\"Green\",\"count\":4285,\"filter\":\"pa('color:Green')\"},{\"value\":\"Purple\",\"valueLabel\":\"Purple\",\"count\":1967,\"filter\":\"pa('color:Purple')\"},{\"value\":\"Beige\",\"valueLabel\":\"Beige\",\"count\":1498,\"filter\":\"pa('color:Beige')\"},{\"value\":\"Turquoise\",\"valueLabel\":\"Turquoise\",\"count\":2513,\"filter\":\"pa('color:Turquoise')\"},{\"value\":\"Blue\",\"valueLabel\":\"Blue\",\"count\":3732,\"filter\":\"pa('color:Blue')\"},{\"value\":\"Orange\",\"valueLabel\":\"Orange\",\"count\":1179,\"filter\":\"pa('color:Orange')\"},{\"value\":\"Pink\",\"valueLabel\":\"Pink\",\"count\":938,\"filter\":\"pa('color:Pink')\"},{\"value\":\"Brown\",\"valueLabel\":\"Brown\",\"count\":1144,\"filter\":\"pa('color:Brown')\"}]},{\"type\":\"productType\",\"typeLabel\":\"productType\",\"values\":[{\"value\":\"T-shirt\",\"valueLabel\":\"T-shirt\",\"count\":24041,\"filter\":\"pa('productType:T-shirt')\"}]},{\"type\":\"size\",\"typeLabel\":\"size\",\"values\":[{\"value\":\"XS\",\"valueLabel\":\"XS\",\"count\":1999,\"filter\":\"pa('size:XS')\"},{\"value\":\"M\",\"valueLabel\":\"M\",\"count\":10208,\"filter\":\"pa('size:M')\"},{\"value\":\"S\",\"valueLabel\":\"S\",\"count\":5313,\"filter\":\"pa('size:S')\"},{\"value\":\"L\",\"valueLabel\":\"L\",\"count\":6753,\"filter\":\"pa('size:L')\"},{\"value\":\"XL\",\"valueLabel\":\"XL\",\"count\":3264,\"filter\":\"pa('size:XL')\"},{\"value\":\"XXL\",\"valueLabel\":\"XXL\",\"count\":1632,\"filter\":\"pa('size:XXL')\"}]},{\"type\":\"colorNames\",\"typeLabel\":\"colorNames\",\"values\":[{\"value\":\"Black\",\"valueLabel\":\"Black\",\"count\":15,\"filter\":\"pa('colorNames:Black')\"},{\"value\":\"White\",\"valueLabel\":\"White\",\"count\":6,\"filter\":\"pa('colorNames:White')\"},{\"value\":\"Grey marl\",\"valueLabel\":\"Grey marl\",\"count\":4,\"filter\":\"pa('colorNames:Grey marl')\"},{\"value\":\"Dark blue\",\"valueLabel\":\"Dark blue\",\"count\":3,\"filter\":\"pa('colorNames:Dark blue')\"}]}],\"dimensions\":[{\"id\":1,\"name\":\"True to Size\",\"label\":\"True to Size\",\"sortOrder\":1,\"required\":false,\"type\":2,\"values\":[{\"id\":1,\"sortOrder\":0,\"label\":\"Small\",\"count\":963,\"filter\":\"dim(1)\"},{\"id\":2,\"sortOrder\":1,\"label\":\"Spot on\",\"count\":18540,\"filter\":\"dim(2)\"},{\"id\":3,\"sortOrder\":2,\"label\":\"Large\",\"count\":1779,\"filter\":\"dim(3)\"}]}],\"userSettings\":{\"shopperProfiles\":[{\"id\":1,\"name\":\"Body Type\",\"label\":\"Body Type\",\"required\":false,\"type\":0,\"displayPublic\":true,\"collectDuringContentSubmit\":true,\"values\":[{\"id\":1,\"sortOrder\":0,\"label\":\"Slim\",\"count\":963,\"filter\":\"sp(1)\"},{\"id\":2,\"sortOrder\":1,\"label\":\"Athletic\",\"count\":18540,\"filter\":\"sp(2)\"},{\"id\":3,\"sortOrder\":2,\"label\":\"Average\",\"count\":1779,\"filter\":\"sp(3)\"},{\"id\":4,\"sortOrder\":3,\"label\":\"Broad\",\"count\":0,\"filter\":\"sp(4)\"},{\"id\":5,\"sortOrder\":4,\"label\":\"Plus Size\",\"count\":0,\"filter\":\"sp(5)\"}]},{\"id\":2,\"name\":\"Height\",\"label\":\"Height\",\"required\":false,\"type\":0,\"displayPublic\":true,\"collectDuringContentSubmit\":true,\"values\":[{\"id\":6,\"sortOrder\":0,\"label\":\"< 5'1\",\"count\":0,\"filter\":\"sp(6)\"},{\"id\":7,\"sortOrder\":1,\"label\":\"5'1 - 5'3\",\"count\":0,\"filter\":\"sp(7)\"},{\"id\":8,\"sortOrder\":2,\"label\":\"5'3 - 5'5\",\"count\":0,\"filter\":\"sp(8)\"},{\"id\":9,\"sortOrder\":3,\"label\":\"5'5 - 5'7\",\"count\":0,\"filter\":\"sp(9)\"},{\"id\":10,\"sortOrder\":4,\"label\":\"5'7 - 5'9\",\"count\":0,\"filter\":\"sp(10)\"},{\"id\":11,\"sortOrder\":5,\"label\":\"5'9 -  5'11\",\"count\":0,\"filter\":\"sp(11)\"},{\"id\":12,\"sortOrder\":6,\"label\":\"5'11 - 6'1\",\"count\":0,\"filter\":\"sp(12)\"},{\"id\":13,\"sortOrder\":7,\"label\":\"6'1  - 6'3\",\"count\":0,\"filter\":\"sp(13)\"},{\"id\":14,\"sortOrder\":8,\"label\":\"6'3 - 6'5\",\"count\":0,\"filter\":\"sp(14)\"},{\"id\":15,\"sortOrder\":9,\"label\":\"6'5 - 6'7\",\"count\":0,\"filter\":\"sp(15)\"},{\"id\":16,\"sortOrder\":10,\"label\":\"> 6'7\",\"count\":0,\"filter\":\"sp(16)\"}]}]},\"rating\":[{\"value\":1,\"count\":669,\"filter\":\"rating(1)\"},{\"value\":2,\"count\":552,\"filter\":\"rating(2)\"},{\"value\":3,\"count\":1697,\"filter\":\"rating(3)\"},{\"value\":4,\"count\":5393,\"filter\":\"rating(4)\"},{\"value\":5,\"count\":21012,\"filter\":\"rating(5)\"}]}}"


# Convert the JSON string to a Python dictionary
data_dict = json.loads(text)

print(data_dict)
# Out:
# {'reviews': [{'id': 1679757, 'locale': 'en_IN', 'rating': 5, 'title': None, 'text': 'I love the colour and the material of this T-shirt! I got this for my boyfriend in two colours! Green and Orange and he absolutely loves it as well, it’s very soft and the fabrics is breathable', 'textLength': 193, 'csFlag': False, 'inappropriateFlag': False, 'reviewedFlag': True, 'autoModerated': False, 'published': True, 'incentivized': False, 'upVotes': 0, 'downVotes': 0, 'orderId': '22592452132', 'dimensions': [{'type': 2, 'dimensionId': 1, 'dimensionLabel': 'True to Size', 'value': 2, 'label': ['Spot on']}], 'responses': [], 'tags': [], 'media': {'photo': [], 'video': [], 'audio': []}, 'user': {'nickName': None, 'firstName': None, 'lastName': None, 'emailAddress': None, 'externalId': None, 'city': None, 'state': None, 'country': None, 'ageRange': None, 'badge': None, 'shopperProfiles': [{'id': 3}, {'id': 10}]}, 'reviewedDate': '2022-06-21T12:41:28-04:00', 'purchaseDate': '2022-06-09T06:47:49-04:
# ...

# %%
comments = []

# %%
for comment in data_dict:
    comments.append(data_dict['reviews']['text'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\kunal\OneDrive\Desktop\PDS\project.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/kunal/OneDrive/Desktop/PDS/project.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> for comment in data_dict:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kunal/OneDrive/Desktop/PDS/project.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     comments.append(data_dict['reviews']['text'])
#
# TypeError: list indices must be integers or slices, not str
